# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import tensorflow as tf

# %% [markdown]
# # Train 1-D RNN with VMC

# %%
"""This function will exclusively train the RNN with Variational Monte Carlo."""
from train_VMC import Train_w_VMC 

energy = []
variance = []
cost = []

def main():
    config = {
        'name': '4x4run-VMC-2201-10000', # Can name each experiment so that results saved in a unique directory
        
        #System Parameters
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7, 
        'Omega': 1,
        'delta': 1,
        
        #RNN Parameters
        'RNN': 'OneD', # eventually, we can look at TwoD RNNs
        'nh': 32,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100, # has to do with interactions between Rydberg atoms
        'seed': 1234,
        
        #Training Parameters
        'VMC_epochs':10000,
        'Data_epochs':0, # should be zero when training with VMC only
        'ns': 1000,
        'batch_size': 100, # irrelevant for VMC training
        'data_step': 100, # irrelevant for VMC training
        
        'Print':False, # print energy, var, etc. at each step
        'Write_Data': True, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_VMC(config,energy,variance,cost) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
# Out:
# gru_6/gru_cell_6/kernel:0 (192,)
# gru_6/gru_cell_6/recurrent_kernel:0 (3072,)
# gru_6/gru_cell_6/bias:0 (192,)
# dense_6/kernel:0 (64,)
# dense_6/bias:0 (2,)
# The sum of params is 3522

# %% [markdown]
# # Train 1-D RNN with Data

# %%
"""This function will exclusively train the RNN on Quantum Monte Carlo data."""
from train_data import Train_w_Data

energy = []
variance = []
cost = []

def main():
    config = {
        'name': '4x4run-data-1500', # Can name each experiment so that results saved in a unique directory
        
        #System Parameters
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7, 
        'Omega': 1,
        'delta': 1,
        
        #RNN Parameters
        'RNN': 'OneD', # eventually, we can look at TwoD RNNs
        'nh': 32,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100, # has to do with interactions between Rydberg atoms
        'seed': 1234,
        
        #Training Parameters
        'VMC_epochs':0, # should be zero when training with Data only
        'Data_epochs':500, 
        'ns': 1000,
        'batch_size': 100, # number of data points presented to RNN at a time
        'data_step': 100, # used to generate a dataset without autocorrelated samples (bc QMC data)
        
        'Print':False, # print energy, var, etc. at each step
        'Write_Data': True, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return Train_w_Data(config,energy,variance,cost) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v,c = main() # can also access e, v, c and make new plots after training is complete (ie to zoom in)
# Out:
# Training a one-D RNN wave function with 32 hidden units and shared weights.
# gru_1/gru_cell_1/kernel:0 (192,)
# gru_1/gru_cell_1/recurrent_kernel:0 (3072,)
# gru_1/gru_cell_1/bias:0 (192,)
# dense_1/kernel:0 (64,)
# dense_1/bias:0 (2,)
# The sum of params is 3522
# The experimental parameters are: V = 7, delta = 1, Omega = 1.
# The system is an array of 4 by 4 Rydberg Atoms
# Tracing!
# Tracing!
# Step #1
# Energy = 0.5703040957450867
# Variance = 15.686446189880371
#
# Step #2
# Energy = 0.10815519094467163
# Variance = 7.038118362426758
#
# Step #3
# Energy = -0.0207472275942564
# Variance = 5.02666711807251
#
# Step #4
# Energy = -0.062243178486824036
# Variance = 4.092535495758057
#
# Step #5
# Energy = -0.029706204310059547
# Variance = 4.989920139312744
#
# Step #6
# Energy = -0.019331887364387512
# Variance = 5.05437707901001
#
# Step #7
# Energy = -0.0415092408657074
# Variance = 4.142836093902588
#
# Step #8
# Energy = -0.11473603546619415
# Variance = 3.583805561065674
#
# ...

# %% [markdown]
# # Train 1-D RNN with Data then VMC

# %%
"""This function will train RNN using data THEN VMC."""
from train_hybrid import run_DataPlusVMC

energy = []
variance = []

def main():
    config = {
        'name': '4x4run-perfect-22-01-800vmc', # Can name each experiment so that results saved in a unique directory
        
        #System Parameters
        'Lx': 4,  # number of sites in x-direction                    
        'Ly': 4,  # number of sites in the y-direction
        'V': 7, 
        'Omega': 1,
        'delta': 1,
        
        #RNN Parameters
        'RNN': 'OneD', # eventually, we can look at TwoD RNNs
        'nh': 32,  # number of hidden units
        'lr': 1e-3,  # learning rate
        'weight_sharing': True,
        'trunc': 100, # has to do with interactions between Rydberg atoms
        'seed': 1234,
        
        #Training Parameters
        'VMC_epochs':800, # number of training steps using VMC
        'Data_epochs':300, # number of training steps using data (these are first)
        'ns': 1000,
        'batch_size': 100,
        'data_step': 100,
        
        'Print':False, # print energy, var, etc. at each step
        'Write_Data': True, # save results (helpful when going to larger systems)
        'Plot': True # plot training curves
        }
    
    return run_DataPlusVMC(config,energy,variance) # make sure this is the same function that is imported above


if __name__ == "__main__":
    model,e,v = main()
# Out:
# gru_2/gru_cell_2/kernel:0 (192,)
# gru_2/gru_cell_2/recurrent_kernel:0 (3072,)
# gru_2/gru_cell_2/bias:0 (192,)
# dense_2/kernel:0 (64,)
# dense_2/bias:0 (2,)
# The sum of params is 3522
# Final Energy -0.4520604941580031 (Exact Energy is -0.4534132086591546)
# Final Error after 1100 epochs is 0.0013527145011514863
# The lowest energy achieved by the model was -0.45546212792396545.
# Final Variance after 1100 epochs is 0.008562310236609645
